# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter("ignore")

# %%
colnames=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
print(len(colnames))
# Out:
# 4

# %%
iris_data=pd.read_csv('/content/drive/MyDrive/iris.txt', sep=" ", names=colnames,header=None)

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.7          4.4           1.5          0.4
# 1           5.5          4.2           1.4          0.2
# 2           5.2          4.1           1.5          0.1
# 3           5.8          4.0           1.2          0.2
# 4           5.4          3.9           1.7          0.4

# %%
iris_data.shape
# Out:
# (150, 4)

# %%
def euclidean_distance(point1, point2):
  dist = np.linalg.norm(point1 - point2)
  return dist

# %%
def manhattan_distance(point1, point2):
    return np.sum([abs(value1 - value2) for value1, value2 in zip(point1, point2)])

# %%
def cosine_similarity(point1,point2):
  return np.dot(point1, point2) / (np.linalg.norm(point1) * np.linalg.norm(point2))

# %%
def sse_k(data,cluster,centroids,K,metric):
  sse = []
  count = [0]*K
  dist1 = 0
  dist2 = 0
  dist3 = 0
  for i in range(data.shape[0]):
    if cluster[i] == 1:
      dist1+= (euclidean_distance(data[i],centroids[0])**2)
      count[0]+=1
    elif cluster[i] == 2:
      dist2+= (euclidean_distance(data[i],centroids[1])**2)
      count[1]+=1
    elif cluster[i] == 3:
      dist3+= (euclidean_distance(data[i],centroids[2])**2)
      count[2]+=1
  # print(count[0])
  # print(count[1])
  # print(count[2])
  # print(dist1)
  # print(dist2)
  # print(dist3)
  #sse_1 = (dist1/count1)+(dist2/count2)+(dist3/count3)
  #sse.append(sse_1)
  sse_1 = dist1+dist2+dist3
  
  #sse_total = np.array(sse)
  return sse_1,count

# %%
def ssb(data,count,centroids,K):
  cent_1 = [0]*len(centroids[0])
  for i in range(K):
    cent_1 += centroids[i]
  
  cent_1 /= K

  
  print(cent_1)
  value = 0
  for i in range(K):
    print((euclidean_distance(centroids[i],cent_1)**2))
    value+= count[i]*(euclidean_distance(centroids[i],cent_1)**2)
    print(value,i)
  return value

# %%
import random
from collections import defaultdict
def K_Means_predict_man(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  #print(x)
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    #print(data[num1])
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=manhattan_distance(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=min(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.mean(label,axis=0)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
import random
from collections import defaultdict
def K_Means_predict(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  print("Initial Cluster Center Indices \n",x)
  print("Initial Cluster Centers\n")
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    print(data[num1])
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=euclidean_distance(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=min(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.mean(label,axis=0)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
import random
from collections import defaultdict
def K_Means_predict_man1(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  #print(x)
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    #print(data[num1])
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=manhattan_distance(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=min(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.median(label,axis=0)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
import random
from collections import defaultdict
def K_Means_predict1(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  #print(x)
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=euclidean_distance(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=min(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.median(label,axis=0)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
import random
from collections import defaultdict
def K_Means_predict_cos(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  #print(x)
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=cosine_similarity(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=max(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.mean(label,axis=0)
      #print(centroid_new)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      #print(a)
      #print(b)
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
import random
from collections import defaultdict
def K_Means_predict_cos1(data,K,max_iter,rand_seed):
  centroids = defaultdict(int)
  cluster = [0]*iris_data1.shape[0]
  random.seed(rand_seed)
  mylist = np.arange(data.shape[0])
  list1 = mylist.tolist()
  x = random.sample(list1,K)
  #print(x)
  for i in range(K):
  #initializing 1st cluster center
    num1 = x[i]
    centroids[i] = data[num1]

  iter=0
  #print(2)

  for iteration in range(max_iter):
    iter+=1
    labels=defaultdict(list)
    #print(data.shape)
    #print(centroids)

    for keys in range(K):
      labels[keys]=[]

    for datapoint1 in range(len(data)):
      distance=[]
      for datapoint2 in range(K):
        dist=cosine_similarity(data[datapoint1],centroids[datapoint2])
        #print("Dp",data[i])
        #print("Cent",centroids[j])
        #print(dist)
        distance.append(dist)
      min_distance=max(distance)
      index=distance.index(min_distance)
      labels[index].append(data[datapoint1])
      cluster[datapoint1] = index+1
      centroid_old=dict(centroids)
    
    for i in range(K):
      label=labels[i]
    
      centroid_new=np.median(label,axis=0)
      centroids[i]=centroid_new
      flag=1

    for i in range(K):
      a=centroids[i]
      b=centroid_old[i]
      temp = 0
      for i in range(len(a)):
        d = abs(a[i] - b[i])
        temp+=d
      if temp !=0:
        flag = 0

      
    if flag==1:
      break
  #print(iter)
  return labels,centroids,cluster,iter

# %%
sse_1 = []
sse_2 = []
sse_3 = []
count11 = []
ssb_k = []
tss_k = []
from collections import defaultdict
iris_data1 = iris_data.to_numpy()
for rand_seed in range(20):
  classes,centroids,cluster,iter=K_Means_predict(iris_data1,3,10000,rand_seed)
  classes1,centroids1,cluster1,iter1=K_Means_predict1(iris_data1,3,10000,rand_seed)
  classes2,centroids2,cluster2,iter2=K_Means_predict_man(iris_data1,3,10000,rand_seed)
  classes3,centroids3,cluster3,iter3=K_Means_predict_man1(iris_data1,3,10000,rand_seed)
  classes4,centroids4,cluster4,iter4=K_Means_predict_cos(iris_data1,3,10000,rand_seed)
  classes5,centroids5,cluster5,iter5=K_Means_predict_cos1(iris_data1,3,10000,rand_seed)
  for i in range(0,3):
    classes[i]=np.array(classes[i]).tolist()
  for i in range(0,3):
    classes1[i]=np.array(classes1[i]).tolist()
  print("Iteration=%d \n"%rand_seed)    
  print("Euclidean")
  print("Mean \n")
  print("Max Iteratins Run=%d \n"%iter)
  print("Final Centroids:",centroids)
  SSE,count = sse_k(iris_data1,cluster,centroids,3,1)
  sse_1.append(SSE)
  SSB = ssb(iris_data1,count,centroids,3)
  ssb_k.append(SSB)
  count11.append(count)
  ssb_k.append(SSB)
  count11.append(count)
  print("Total SSE =%f"%SSE)
  print("Total SSB =%2f \n"%SSB)
  print("\n")
  for i in range(0,3):
    print("Cluster %d"%i,len(classes[i]))
  print("Median \n")
  print("Max Iteratins Run=%d \n"%iter1)
  print("Final Centroids:",centroids1)
  SSE,count = sse_k(iris_data1,cluster1,centroids1,3,1)
  print("Total SSE =%2f"%SSE)
  #print("Total SSB =%2f \n"%SSB)
  print("\n")  
  for i in range(0,3):
    print("Cluster %d"%i,len(classes1[i]))
  print("\n")
  print("Manhattan")
  print("Mean \n")
  print("Max Iteratins Run=%d \n"%iter2)
  print("Final Centroids:",centroids2)
  SSE,count = sse_k(iris_data1,cluster2,centroids2,3,2)
  print("Total SSE =%2f"%SSE)
  print("\n")
  for i in range(0,3):
    print("Cluster %d"%i,len(classes2[i]))
  print("Median \n")
  print("Max Iteratins Run=%d \n"%iter3)
  print("Final Centroids:",centroids3)
  SSE,count = sse_k(iris_data1,cluster3,centroids3,3,2)
  print("Total SSE =%2f"%SSE)
  print("\n")  
  for i in range(0,3):
    print("Cluster %d"%i,len(classes3[i]))
  print("\n")
  print("Cosine")
  print("Mean \n")
  print("Max Iteratins Run=%d \n"%iter4)
  print("Final Centroids:",centroids4)
  SSE,count = sse_k(iris_data1,cluster4,centroids4,3,3)
  print("Total SSE =%2f"%SSE)
  print("\n")
  for i in range(0,3):
    print("Cluster %d"%i,len(classes4[i]))
  print("Median \n")
  print("Max Iteratins Run=%d \n"%iter5)
  print("Final Centroids:",centroids5)
  SSE,count = sse_k(iris_data1,cluster5,centroids5,3,3)
  sse_3.append(SSE)
  print("Total SSE =%2f"%SSE)
  print("\n")  
  for i in range(0,3):
    print("Cluster %d"%i,len(classes5[i]))
  print("\n")
  print("**********XXXXX********")
  #print(centroids)
# Out:
# Initial Cluster Center Indices
#  [98, 107, 10]
# Initial Cluster Centers
#
# [6.4 2.9 4.3 1.3]
# [5.8 2.8 5.1 2.4]
# [5.1 3.8 1.6 0.2]
# Iteration=0
#
# Euclidean
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 1: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 61
# 39
# 50
# 38.29081967213114
# 25.413846153846155
# 15.2404
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 0.4348045249527312
# 26.5230760221166 0
# 4.995531182067555
# 221.34879212275126 1
# 7.662212642538981
# 604.4594242497003 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 61
# 39
# 50
# 39.39000000000001
# 26.93
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 63
# 37
# 50
# 42.05
# 24.02
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 1: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 46
# 54
# 50
# 27.911086956521736
# 48.92722222222223
# 15.2404
# Total SSE =92.078709
#
#
# Cluster 0 46
# Cluster 1 54
# Cluster 2 50
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.95, 2.8 , 4.3 , 1.3 ]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 48
# 52
# 50
# 32.900000000000006
# 48.24999999999998
# 15.420000000000005
# Total SSE =96.570000
#
#
# Cluster 0 48
# Cluster 1 52
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [34, 145, 16]
# Initial Cluster Centers
#
# [4.6 3.4 1.4 0.3]
# [4.5 2.3 1.3 0.3]
# [5.  3.6 1.4 0.2]
# Iteration=1
#
# Euclidean
# Mean
#
# Max Iteratins Run=13
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 2: array([6.85384615, 3.07692308, 5.71538462, 2.05384615])})
# 50
# 61
# 39
# 15.2404
# 38.29081967213114
# 25.413846153846155
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 7.662212642538984
# 383.1106321269492 0
# 0.4348045249527312
# 409.6337081490658 1
# 4.995531182067554
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 50
# Cluster 1 61
# Cluster 2 39
# Median
#
# Max Iteratins Run=18
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([5.9, 2.8, 4.5, 1.4]), 2: array([6.7, 3. , 5.6, 2.1])})
# 50
# 61
# 39
# 15.420000000000005
# 39.39000000000001
# 26.93
# Total SSE =81.740000
#
#
# Cluster 0 50
# Cluster 1 61
# Cluster 2 39
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 2: array([6.87027027, 3.08648649, 5.74594595, 2.08918919])})
# 50
# 63
# 37
# 15.2404
# 41.31492063492064
# 22.58810810810811
# Total SSE =79.143429
#
#
# Cluster 0 50
# Cluster 1 63
# Cluster 2 37
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([5.7 , 2.7 , 4.15, 1.3 ]), 2: array([6.5, 3. , 5.3, 1.9])})
# 50
# 38
# 62
# 15.420000000000005
# 17.555
# 52.959999999999994
# Total SSE =85.935000
#
#
# Cluster 0 50
# Cluster 1 38
# Cluster 2 62
#
#
# Cosine
# Mean
#
# Max Iteratins Run=9
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.05416667, 3.65      , 1.42916667, 0.26666667]), 1: array([6.262, 2.872, 4.906, 1.676]), 2: array([4.96153846, 3.20384615, 1.49615385, 0.22307692])})
# 24
# 100
# 26
# 7.2225
# 139.796
# 5.346923076923079
# Total SSE =152.365423
#
#
# Cluster 0 24
# Cluster 1 100
# Cluster 2 26
# Median
#
# Max Iteratins Run=9
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.9, 3.1, 1.5, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([5.1, 3.5, 1.4, 0.2])})
# 17
# 100
# 33
# 2.8600000000000008
# 140.60000000000002
# 9.690000000000001
# Total SSE =153.150000
#
#
# Cluster 0 17
# Cluster 1 100
# Cluster 2 33
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [14, 23, 21]
# Initial Cluster Centers
#
# [5.3 3.7 1.5 0.2]
# [5.5 3.5 1.3 0.2]
# [5.1 3.5 1.4 0.2]
# Iteration=2
#
# Euclidean
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.30103093, 2.88659794, 4.95876289, 1.69587629]), 1: array([5.28333333, 3.70833333, 1.49166667, 0.27916667]), 2: array([4.77586207, 3.07241379, 1.62068966, 0.29655172])})
# 97
# 24
# 29
# 123.79587628865977
# 3.8495833333333342
# 15.808275862068967
# [5.45340878 3.22244835 2.69037307 0.75719823]
# 6.857967680295207
# 665.2228649886351 0
# 1.9304210810745257
# 711.5529709344238 1
# 1.8379977178688256
# 764.8549047526197 2
# Total SSE =143.453735
# Total SSB =764.854905
#
#
#
# Cluster 0 97
# Cluster 1 24
# Cluster 2 29
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.3, 2.9, 4.9, 1.6]), 1: array([5.4, 3.8, 1.5, 0.2]), 2: array([4.9, 3.2, 1.4, 0.2])})
# 98
# 17
# 35
# 130.01000000000002
# 2.7500000000000013
# 14.420000000000003
# Total SSE =147.180000
#
#
# Cluster 0 98
# Cluster 1 17
# Cluster 2 35
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=15
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.4, 3.8, 1.5, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([4.9, 3.2, 1.4, 0.2])})
# 17
# 97
# 36
# 2.7500000000000013
# 125.04000000000002
# 19.490000000000006
# Total SSE =147.280000
#
#
# Cluster 0 17
# Cluster 1 97
# Cluster 2 36
#
#
# Cosine
# Mean
#
# Max Iteratins Run=9
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.262, 2.872, 4.906, 1.676]), 1: array([4.96153846, 3.20384615, 1.49615385, 0.22307692]), 2: array([5.05416667, 3.65      , 1.42916667, 0.26666667])})
# 100
# 26
# 24
# 139.796
# 5.346923076923079
# 7.2225
# Total SSE =152.365423
#
#
# Cluster 0 100
# Cluster 1 26
# Cluster 2 24
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.3, 2.9, 4.9, 1.6]), 1: array([5.1, 3.6, 1.4, 0.2]), 2: array([4.9, 3.3, 1.5, 0.2])})
# 100
# 21
# 29
# 140.60000000000002
# 6.410000000000001
# 6.689999999999999
# Total SSE =153.700000
#
#
# Cluster 0 100
# Cluster 1 21
# Cluster 2 29
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [60, 139, 33]
# Initial Cluster Centers
#
# [6.7 3.1 4.7 1.5]
# [5.5 2.4 3.8 1.1]
# [5.  3.4 1.5 0.2]
# Iteration=3
#
# Euclidean
# Mean
#
# Max Iteratins Run=11
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 1: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 39
# 61
# 50
# 25.413846153846155
# 38.29081967213114
# 15.2404
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 4.995531182067555
# 194.82571610063465 0
# 0.4348045249527312
# 221.34879212275126 1
# 7.662212642538981
# 604.4594242497003 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 39
# Cluster 1 61
# Cluster 2 50
# Median
#
# Max Iteratins Run=16
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.6, 2.1]), 1: array([5.9, 2.8, 4.5, 1.4]), 2: array([5. , 3.4, 1.5, 0.2])})
# 39
# 61
# 50
# 26.93
# 39.39000000000001
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 39
# Cluster 1 61
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=11
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 1: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 37
# 63
# 50
# 22.58810810810811
# 41.31492063492064
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 37
# Cluster 1 63
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.5, 3. , 5.3, 1.9]), 1: array([5.7 , 2.7 , 4.15, 1.3 ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 62
# 38
# 50
# 52.959999999999994
# 17.555
# 15.420000000000005
# Total SSE =85.935000
#
#
# Cluster 0 62
# Cluster 1 38
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.52      , 2.96545455, 5.48      , 1.98545455]), 1: array([5.94666667, 2.75777778, 4.20444444, 1.29777778]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 55
# 45
# 50
# 51.008727272727285
# 27.61066666666667
# 15.2404
# Total SSE =93.859794
#
#
# Cluster 0 55
# Cluster 1 45
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.4, 3. , 5.5, 2. ]), 1: array([5.85, 2.8 , 4.25, 1.3 ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 54
# 46
# 50
# 50.00999999999998
# 28.410000000000007
# 15.420000000000005
# Total SSE =93.840000
#
#
# Cluster 0 54
# Cluster 1 46
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [60, 77, 26]
# Initial Cluster Centers
#
# [6.7 3.1 4.7 1.5]
# [6.7 3.  5.  1.7]
# [6.  3.4 4.5 1.6]
# Iteration=4
#
# Euclidean
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9016129 , 2.7483871 , 4.39354839, 1.43387097]), 1: array([6.85      , 3.07368421, 5.74210526, 2.07105263]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 62
# 38
# 50
# 39.820967741935476
# 23.87947368421053
# 15.2404
# [5.9192043  3.08002377 3.86655122 1.2496412 ]
# 0.4219589646672686
# 26.161455809370654 0
# 5.058840544431341
# 218.3973964977616 1
# 7.7317365999521455
# 604.9842264953688 2
# Total SSE =78.940841
# Total SSB =604.984226
#
#
#
# Cluster 0 62
# Cluster 1 38
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 61
# 39
# 50
# 39.39000000000001
# 26.93
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 63
# 37
# 50
# 42.05
# 24.02
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.94666667, 2.75777778, 4.20444444, 1.29777778]), 1: array([6.52      , 2.96545455, 5.48      , 1.98545455]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 45
# 55
# 50
# 27.61066666666667
# 51.008727272727285
# 15.2404
# Total SSE =93.859794
#
#
# Cluster 0 45
# Cluster 1 55
# Cluster 2 50
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.85, 2.8 , 4.25, 1.3 ]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 46
# 54
# 50
# 28.410000000000007
# 50.00999999999998
# 15.420000000000005
# Total SSE =93.840000
#
#
# Cluster 0 46
# Cluster 1 54
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [65, 91, 135]
# Initial Cluster Centers
#
# [4.9 3.1 1.5 0.1]
# [4.4 3.  1.3 0.2]
# [4.9 2.5 4.5 1.7]
# Iteration=5
#
# Euclidean
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.21612903, 3.53870968, 1.68064516, 0.35806452]), 1: array([4.70909091, 3.10909091, 1.39545455, 0.19090909]), 2: array([6.30103093, 2.88659794, 4.95876289, 1.69587629])})
# 31
# 22
# 97
# 18.639354838709682
# 2.8440909090909097
# 123.79587628865977
# [5.40875029 3.17813284 2.67828753 0.7482833 ]
# 1.3146795996282643
# 40.755067588476194 0
# 2.4506165138091647
# 94.66863089227782 1
# 6.979657658888678
# 771.6954238044797 2
# Total SSE =145.279322
# Total SSB =771.695424
#
#
#
# Cluster 0 31
# Cluster 1 22
# Cluster 2 97
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.1, 3.5, 1.5, 0.2]), 1: array([4.8, 3.1, 1.4, 0.2]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 30
# 23
# 97
# 6.540000000000004
# 16.32
# 125.04000000000002
# Total SSE =147.900000
#
#
# Cluster 0 30
# Cluster 1 23
# Cluster 2 97
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=9
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.19677419, 3.63225806, 1.47096774, 0.28064516]), 1: array([4.74782609, 2.93478261, 1.76956522, 0.33043478]), 2: array([6.31458333, 2.89583333, 4.97395833, 1.703125  ])})
# 31
# 23
# 96
# 6.08967741935484
# 18.18695652173913
# 118.65187500000002
# Total SSE =142.928509
#
#
# Cluster 0 31
# Cluster 1 23
# Cluster 2 96
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.1, 3.5, 1.5, 0.2]), 1: array([4.75, 3.1 , 1.4 , 0.2 ]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 31
# 22
# 97
# 10.600000000000005
# 12.365000000000002
# 125.04000000000002
# Total SSE =148.005000
#
#
# Cluster 0 31
# Cluster 1 22
# Cluster 2 97
#
#
# Cosine
# Mean
#
# Max Iteratins Run=12
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.96153846, 3.20384615, 1.49615385, 0.22307692]), 1: array([5.05416667, 3.65      , 1.42916667, 0.26666667]), 2: array([6.262, 2.872, 4.906, 1.676])})
# 26
# 24
# 100
# 5.346923076923079
# 7.2225
# 139.796
# Total SSE =152.365423
#
#
# Cluster 0 26
# Cluster 1 24
# Cluster 2 100
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.9, 3.1, 1.5, 0.2]), 1: array([5.1, 3.5, 1.5, 0.2]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 13
# 37
# 100
# 2.3000000000000003
# 10.839999999999998
# 140.60000000000002
# Total SSE =153.740000
#
#
# Cluster 0 13
# Cluster 1 37
# Cluster 2 100
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [146, 20, 124]
# Initial Cluster Centers
#
# [6.  2.2 5.  1.5]
# [5.1 3.5 1.4 0.3]
# [5.2 2.7 3.9 1.4]
# Iteration=6
#
# Euclidean
# Mean
#
# Max Iteratins Run=10
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.88360656, 2.74098361, 4.38852459, 1.43442623])})
# 39
# 50
# 61
# 25.413846153846155
# 15.2404
# 38.29081967213114
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 4.995531182067554
# 194.8257161006346 0
# 7.662212642538984
# 577.9363482275838 1
# 0.4348045249527312
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 39
# Cluster 1 50
# Cluster 2 61
# Median
#
# Max Iteratins Run=16
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.6, 2.1]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 39
# 50
# 61
# 26.93
# 15.420000000000005
# 39.39000000000001
# Total SSE =81.740000
#
#
# Cluster 0 39
# Cluster 1 50
# Cluster 2 61
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=11
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333])})
# 37
# 50
# 63
# 22.58810810810811
# 15.2404
# 41.31492063492064
# Total SSE =79.143429
#
#
# Cluster 0 37
# Cluster 1 50
# Cluster 2 63
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.5, 3. , 5.3, 1.9]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.7 , 2.7 , 4.15, 1.3 ])})
# 62
# 50
# 38
# 52.959999999999994
# 15.420000000000005
# 17.555
# Total SSE =85.935000
#
#
# Cluster 0 62
# Cluster 1 50
# Cluster 2 38
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.93913043, 2.76304348, 4.21086957, 1.30217391])})
# 54
# 50
# 46
# 48.92722222222223
# 15.2404
# 27.911086956521736
# Total SSE =92.078709
#
#
# Cluster 0 54
# Cluster 1 50
# Cluster 2 46
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.4, 3. , 5.5, 2. ]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.95, 2.8 , 4.3 , 1.3 ])})
# 52
# 50
# 48
# 48.24999999999998
# 15.420000000000005
# 32.900000000000006
# Total SSE =96.570000
#
#
# Cluster 0 52
# Cluster 1 50
# Cluster 2 48
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [82, 38, 101]
# Initial Cluster Centers
#
# [5.4 3.  4.5 1.5]
# [6.7 3.3 5.7 2.1]
# [5.6 2.9 3.6 1.3]
# Iteration=7
#
# Euclidean
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9016129 , 2.7483871 , 4.39354839, 1.43387097]), 1: array([6.85      , 3.07368421, 5.74210526, 2.07105263]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 62
# 38
# 50
# 39.820967741935476
# 23.87947368421053
# 15.2404
# [5.9192043  3.08002377 3.86655122 1.2496412 ]
# 0.4219589646672686
# 26.161455809370654 0
# 5.058840544431341
# 218.3973964977616 1
# 7.7317365999521455
# 604.9842264953688 2
# Total SSE =78.940841
# Total SSB =604.984226
#
#
#
# Cluster 0 62
# Cluster 1 38
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 61
# 39
# 50
# 39.39000000000001
# 26.93
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 63
# 37
# 50
# 42.05
# 24.02
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 1: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 46
# 54
# 50
# 27.911086956521736
# 48.92722222222223
# 15.2404
# Total SSE =92.078709
#
#
# Cluster 0 46
# Cluster 1 54
# Cluster 2 50
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.95, 2.8 , 4.3 , 1.3 ]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 48
# 52
# 50
# 32.900000000000006
# 48.24999999999998
# 15.420000000000005
# Total SSE =96.570000
#
#
# Cluster 0 48
# Cluster 1 52
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [58, 94, 96]
# Initial Cluster Centers
#
# [6.9 3.1 5.1 2.3]
# [6.3 2.9 5.6 1.8]
# [6.6 2.9 4.6 1.3]
# Iteration=8
#
# Euclidean
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.85      , 3.07368421, 5.74210526, 2.07105263]), 1: array([5.9016129 , 2.7483871 , 4.39354839, 1.43387097]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 38
# 62
# 50
# 23.87947368421053
# 39.820967741935476
# 15.2404
# [5.9192043  3.08002377 3.86655122 1.2496412 ]
# 5.058840544431341
# 192.23594068839094 0
# 0.4219589646672686
# 218.3973964977616 1
# 7.7317365999521455
# 604.9842264953688 2
# Total SSE =78.940841
# Total SSB =604.984226
#
#
#
# Cluster 0 38
# Cluster 1 62
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.6, 2.1]), 1: array([5.9, 2.8, 4.5, 1.4]), 2: array([5. , 3.4, 1.5, 0.2])})
# 39
# 61
# 50
# 26.93
# 39.39000000000001
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 39
# Cluster 1 61
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 1: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 37
# 63
# 50
# 22.58810810810811
# 41.31492063492064
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 37
# Cluster 1 63
# Cluster 2 50
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.7, 2.1]), 1: array([5.9, 2.8, 4.5, 1.4]), 2: array([5. , 3.4, 1.5, 0.2])})
# 37
# 63
# 50
# 24.02
# 42.05
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 37
# Cluster 1 63
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 1: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 46
# 54
# 50
# 27.911086956521736
# 48.92722222222223
# 15.2404
# Total SSE =92.078709
#
#
# Cluster 0 46
# Cluster 1 54
# Cluster 2 50
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.3, 1.3]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 47
# 53
# 50
# 29.06
# 49.13999999999998
# 15.420000000000005
# Total SSE =93.620000
#
#
# Cluster 0 47
# Cluster 1 53
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [118, 95, 68]
# Initial Cluster Centers
#
# [5.8 2.7 5.1 1.9]
# [6.1 2.9 4.7 1.4]
# [7.7 3.  6.1 2.3]
# Iteration=9
#
# Euclidean
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9016129 , 2.7483871 , 4.39354839, 1.43387097]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.85      , 3.07368421, 5.74210526, 2.07105263])})
# 62
# 50
# 38
# 39.820967741935476
# 15.2404
# 23.87947368421053
# [5.9192043  3.08002377 3.86655122 1.2496412 ]
# 0.4219589646672686
# 26.161455809370654 0
# 7.7317365999521455
# 412.7482858069779 1
# 5.058840544431341
# 604.9842264953688 2
# Total SSE =78.940841
# Total SSB =604.984226
#
#
#
# Cluster 0 62
# Cluster 1 50
# Cluster 2 38
# Median
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([6.7, 3. , 5.6, 2.1])})
# 61
# 50
# 39
# 39.39000000000001
# 15.420000000000005
# 26.93
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 50
# Cluster 2 39
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.87027027, 3.08648649, 5.74594595, 2.08918919])})
# 63
# 50
# 37
# 41.31492063492064
# 15.2404
# 22.58810810810811
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 50
# Cluster 2 37
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([6.7, 3. , 5.7, 2.1])})
# 63
# 50
# 37
# 42.05
# 15.420000000000005
# 24.02
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 50
# Cluster 2 37
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.93913043, 2.76304348, 4.21086957, 1.30217391])})
# 54
# 50
# 46
# 48.92722222222223
# 15.2404
# 27.911086956521736
# Total SSE =92.078709
#
#
# Cluster 0 54
# Cluster 1 50
# Cluster 2 46
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.4, 3. , 5.5, 2. ]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.95, 2.8 , 4.3 , 1.3 ])})
# 52
# 50
# 48
# 48.24999999999998
# 15.420000000000005
# 32.900000000000006
# Total SSE =96.570000
#
#
# Cluster 0 52
# Cluster 1 50
# Cluster 2 48
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [146, 8, 109]
# Initial Cluster Centers
#
# [6.  2.2 5.  1.5]
# [5.1 3.8 1.9 0.4]
# [5.6 2.8 4.9 2. ]
# Iteration=10
#
# Euclidean
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.85384615, 3.07692308, 5.71538462, 2.05384615])})
# 61
# 50
# 39
# 38.29081967213114
# 15.2404
# 25.413846153846155
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 0.4348045249527312
# 26.5230760221166 0
# 7.662212642538984
# 409.6337081490658 1
# 4.995531182067554
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 61
# Cluster 1 50
# Cluster 2 39
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([6.7, 3. , 5.6, 2.1])})
# 61
# 50
# 39
# 39.39000000000001
# 15.420000000000005
# 26.93
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 50
# Cluster 2 39
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.87027027, 3.08648649, 5.74594595, 2.08918919])})
# 63
# 50
# 37
# 41.31492063492064
# 15.2404
# 22.58810810810811
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 50
# Cluster 2 37
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([6.7, 3. , 5.7, 2.1])})
# 63
# 50
# 37
# 42.05
# 15.420000000000005
# 24.02
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 50
# Cluster 2 37
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.94666667, 2.75777778, 4.20444444, 1.29777778]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.52      , 2.96545455, 5.48      , 1.98545455])})
# 45
# 50
# 55
# 27.61066666666667
# 15.2404
# 51.008727272727285
# Total SSE =93.859794
#
#
# Cluster 0 45
# Cluster 1 50
# Cluster 2 55
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.85, 2.8 , 4.25, 1.3 ]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([6.4, 3. , 5.5, 2. ])})
# 46
# 50
# 54
# 28.410000000000007
# 15.420000000000005
# 50.00999999999998
# Total SSE =93.840000
#
#
# Cluster 0 46
# Cluster 1 50
# Cluster 2 54
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [115, 143, 119]
# Initial Cluster Centers
#
# [5.7 2.8 4.1 1.3]
# [5.5 2.3 4.  1.3]
# [5.8 2.7 5.1 1.9]
# Iteration=11
#
# Euclidean
# Mean
#
# Max Iteratins Run=13
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([6.85384615, 3.07692308, 5.71538462, 2.05384615])})
# 61
# 50
# 39
# 38.29081967213114
# 15.2404
# 25.413846153846155
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 0.4348045249527312
# 26.5230760221166 0
# 7.662212642538984
# 409.6337081490658 1
# 4.995531182067554
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 61
# Cluster 1 50
# Cluster 2 39
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.4, 3.8, 1.5, 0.2]), 1: array([4.9, 3.2, 1.4, 0.2]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 17
# 35
# 98
# 2.7500000000000013
# 14.420000000000003
# 130.01000000000002
# Total SSE =147.180000
#
#
# Cluster 0 17
# Cluster 1 35
# Cluster 2 98
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=12
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 2: array([6.87027027, 3.08648649, 5.74594595, 2.08918919])})
# 50
# 63
# 37
# 15.2404
# 41.31492063492064
# 22.58810810810811
# Total SSE =79.143429
#
#
# Cluster 0 50
# Cluster 1 63
# Cluster 2 37
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([5.7 , 2.7 , 4.15, 1.3 ]), 2: array([6.5, 3. , 5.3, 1.9])})
# 50
# 38
# 62
# 15.420000000000005
# 17.555
# 52.959999999999994
# Total SSE =85.935000
#
#
# Cluster 0 50
# Cluster 1 38
# Cluster 2 62
#
#
# Cosine
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 2: array([6.53703704, 2.96481481, 5.49814815, 1.99444444])})
# 50
# 46
# 54
# 15.2404
# 27.911086956521736
# 48.92722222222223
# Total SSE =92.078709
#
#
# Cluster 0 50
# Cluster 1 46
# Cluster 2 54
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([5.9, 2.8, 4.3, 1.3]), 2: array([6.4, 3. , 5.5, 2. ])})
# 50
# 47
# 53
# 15.420000000000005
# 29.06
# 49.13999999999998
# Total SSE =93.620000
#
#
# Cluster 0 50
# Cluster 1 47
# Cluster 2 53
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [121, 68, 135]
# Initial Cluster Centers
#
# [6.3 2.7 4.9 1.8]
# [7.7 3.  6.1 2.3]
# [4.9 2.5 4.5 1.7]
# Iteration=12
#
# Euclidean
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9016129 , 2.7483871 , 4.39354839, 1.43387097]), 1: array([6.85      , 3.07368421, 5.74210526, 2.07105263]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 62
# 38
# 50
# 39.820967741935476
# 23.87947368421053
# 15.2404
# [5.9192043  3.08002377 3.86655122 1.2496412 ]
# 0.4219589646672686
# 26.161455809370654 0
# 5.058840544431341
# 218.3973964977616 1
# 7.7317365999521455
# 604.9842264953688 2
# Total SSE =78.940841
# Total SSB =604.984226
#
#
#
# Cluster 0 62
# Cluster 1 38
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 61
# 39
# 50
# 39.39000000000001
# 26.93
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 63
# 37
# 50
# 42.05
# 24.02
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 2: array([6.53703704, 2.96481481, 5.49814815, 1.99444444])})
# 50
# 46
# 54
# 15.2404
# 27.911086956521736
# 48.92722222222223
# Total SSE =92.078709
#
#
# Cluster 0 50
# Cluster 1 46
# Cluster 2 54
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([5.9, 2.8, 4.3, 1.3]), 2: array([6.4, 3. , 5.5, 2. ])})
# 50
# 47
# 53
# 15.420000000000005
# 29.06
# 49.13999999999998
# Total SSE =93.620000
#
#
# Cluster 0 50
# Cluster 1 47
# Cluster 2 53
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [66, 74, 47]
# Initial Cluster Centers
#
# [4.9 3.1 1.5 0.1]
# [6.7 3.  5.2 2.3]
# [5.9 3.2 4.8 1.8]
# Iteration=13
#
# Euclidean
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 2: array([5.88360656, 2.74098361, 4.38852459, 1.43442623])})
# 50
# 39
# 61
# 15.2404
# 25.413846153846155
# 38.29081967213114
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 7.662212642538984
# 383.1106321269492 0
# 4.995531182067554
# 577.9363482275838 1
# 0.4348045249527312
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 50
# Cluster 1 39
# Cluster 2 61
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 50
# 39
# 61
# 15.420000000000005
# 26.93
# 39.39000000000001
# Total SSE =81.740000
#
#
# Cluster 0 50
# Cluster 1 39
# Cluster 2 61
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333])})
# 50
# 37
# 63
# 15.2404
# 22.58810810810811
# 41.31492063492064
# Total SSE =79.143429
#
#
# Cluster 0 50
# Cluster 1 37
# Cluster 2 63
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 50
# 37
# 63
# 15.420000000000005
# 24.02
# 42.05
# Total SSE =81.490000
#
#
# Cluster 0 50
# Cluster 1 37
# Cluster 2 63
#
#
# Cosine
# Mean
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 2: array([5.93913043, 2.76304348, 4.21086957, 1.30217391])})
# 50
# 54
# 46
# 15.2404
# 48.92722222222223
# 27.911086956521736
# Total SSE =92.078709
#
#
# Cluster 0 50
# Cluster 1 54
# Cluster 2 46
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5.9, 2.8, 4.3, 1.3])})
# 50
# 53
# 47
# 15.420000000000005
# 49.13999999999998
# 29.06
# Total SSE =93.620000
#
#
# Cluster 0 50
# Cluster 1 53
# Cluster 2 47
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [27, 134, 63]
# Initial Cluster Centers
#
# [4.8 3.4 1.9 0.2]
# [6.3 2.5 4.9 1.5]
# [4.6 3.1 1.5 0.2]
# Iteration=14
#
# Euclidean
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.21612903, 3.53870968, 1.68064516, 0.35806452]), 1: array([6.30103093, 2.88659794, 4.95876289, 1.69587629]), 2: array([4.70909091, 3.10909091, 1.39545455, 0.19090909])})
# 31
# 97
# 22
# 18.639354838709682
# 123.79587628865977
# 2.8440909090909097
# [5.40875029 3.17813284 2.67828753 0.7482833 ]
# 1.3146795996282643
# 40.755067588476194 0
# 6.979657658888678
# 717.781860500678 1
# 2.4506165138091647
# 771.6954238044797 2
# Total SSE =145.279322
# Total SSB =771.695424
#
#
#
# Cluster 0 31
# Cluster 1 97
# Cluster 2 22
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.1, 3.5, 1.5, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([4.8, 3.1, 1.4, 0.2])})
# 30
# 97
# 23
# 6.540000000000004
# 125.04000000000002
# 16.32
# Total SSE =147.900000
#
#
# Cluster 0 30
# Cluster 1 97
# Cluster 2 23
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=8
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.19677419, 3.63225806, 1.47096774, 0.28064516]), 1: array([6.31458333, 2.89583333, 4.97395833, 1.703125  ]), 2: array([4.74782609, 2.93478261, 1.76956522, 0.33043478])})
# 31
# 96
# 23
# 6.08967741935484
# 118.65187500000002
# 18.18695652173913
# Total SSE =142.928509
#
#
# Cluster 0 31
# Cluster 1 96
# Cluster 2 23
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.1, 3.5, 1.5, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([4.75, 3.1 , 1.4 , 0.2 ])})
# 31
# 97
# 22
# 10.600000000000005
# 125.04000000000002
# 12.365000000000002
# Total SSE =148.005000
#
#
# Cluster 0 31
# Cluster 1 97
# Cluster 2 22
#
#
# Cosine
# Mean
#
# Max Iteratins Run=2
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.95, 3.6 , 1.9 , 0.3 ]), 1: array([6.262, 2.872, 4.906, 1.676]), 2: array([5.00833333, 3.41041667, 1.44583333, 0.24166667])})
# 2
# 100
# 48
# 0.14499999999999993
# 139.796
# 14.617291666666668
# Total SSE =154.558292
#
#
# Cluster 0 2
# Cluster 1 100
# Cluster 2 48
# Median
#
# Max Iteratins Run=2
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.95, 3.6 , 1.9 , 0.3 ]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([5. , 3.4, 1.5, 0.2])})
# 2
# 100
# 48
# 0.14499999999999993
# 140.60000000000002
# 14.850000000000001
# Total SSE =155.595000
#
#
# Cluster 0 2
# Cluster 1 100
# Cluster 2 48
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [53, 2, 133]
# Initial Cluster Centers
#
# [4.4 3.2 1.3 0.2]
# [5.2 4.1 1.5 0.1]
# [6.3 2.5 5.  1.9]
# Iteration=15
#
# Euclidean
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.77586207, 3.07241379, 1.62068966, 0.29655172]), 1: array([5.28333333, 3.70833333, 1.49166667, 0.27916667]), 2: array([6.30103093, 2.88659794, 4.95876289, 1.69587629])})
# 29
# 24
# 97
# 15.808275862068967
# 3.8495833333333342
# 123.79587628865977
# [5.45340878 3.22244835 2.69037307 0.75719823]
# 1.8379977178688256
# 53.30193381819594 0
# 1.9304210810745257
# 99.63203976398455 1
# 6.857967680295207
# 764.8549047526196 2
# Total SSE =143.453735
# Total SSB =764.854905
#
#
#
# Cluster 0 29
# Cluster 1 24
# Cluster 2 97
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.8, 3.1, 1.4, 0.2]), 1: array([5.2, 3.6, 1.5, 0.2]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 26
# 27
# 97
# 16.87
# 4.8900000000000015
# 125.04000000000002
# Total SSE =146.800000
#
#
# Cluster 0 26
# Cluster 1 27
# Cluster 2 97
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.74782609, 2.93478261, 1.76956522, 0.33043478]), 1: array([5.19677419, 3.63225806, 1.47096774, 0.28064516]), 2: array([6.31458333, 2.89583333, 4.97395833, 1.703125  ])})
# 23
# 31
# 96
# 18.18695652173913
# 6.08967741935484
# 118.65187500000002
# Total SSE =142.928509
#
#
# Cluster 0 23
# Cluster 1 31
# Cluster 2 96
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.8, 3.1, 1.4, 0.2]), 1: array([5.2, 3.6, 1.5, 0.2]), 2: array([6.3 , 2.9 , 4.9 , 1.65])})
# 27
# 27
# 96
# 23.17
# 4.8900000000000015
# 119.47000000000001
# Total SSE =147.530000
#
#
# Cluster 0 27
# Cluster 1 27
# Cluster 2 96
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([4.96470588, 3.26764706, 1.5       , 0.23823529]), 1: array([5.09375, 3.7375 , 1.3875 , 0.25625]), 2: array([6.262, 2.872, 4.906, 1.676])})
# 34
# 16
# 100
# 7.01235294117647
# 5.50375
# 139.796
# Total SSE =152.312103
#
#
# Cluster 0 34
# Cluster 1 16
# Cluster 2 100
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.3, 1.5, 0.2]), 1: array([5.1, 3.8, 1.4, 0.2]), 2: array([6.3, 2.9, 4.9, 1.6])})
# 35
# 15
# 100
# 7.389999999999999
# 5.5600000000000005
# 140.60000000000002
# Total SSE =153.550000
#
#
# Cluster 0 35
# Cluster 1 15
# Cluster 2 100
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [92, 120, 123]
# Initial Cluster Centers
#
# [4.3 3.  1.1 0.1]
# [6.  2.7 5.1 1.6]
# [5.8 2.7 4.1 1. ]
# Iteration=16
#
# Euclidean
# Mean
#
# Max Iteratins Run=10
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 2: array([5.88360656, 2.74098361, 4.38852459, 1.43442623])})
# 50
# 39
# 61
# 15.2404
# 25.413846153846155
# 38.29081967213114
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 7.662212642538984
# 383.1106321269492 0
# 4.995531182067554
# 577.9363482275838 1
# 0.4348045249527312
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 50
# Cluster 1 39
# Cluster 2 61
# Median
#
# Max Iteratins Run=16
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 50
# 39
# 61
# 15.420000000000005
# 26.93
# 39.39000000000001
# Total SSE =81.740000
#
#
# Cluster 0 50
# Cluster 1 39
# Cluster 2 61
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=11
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333])})
# 50
# 37
# 63
# 15.2404
# 22.58810810810811
# 41.31492063492064
# Total SSE =79.143429
#
#
# Cluster 0 50
# Cluster 1 37
# Cluster 2 63
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.5, 3. , 5.3, 1.9]), 2: array([5.7 , 2.7 , 4.15, 1.3 ])})
# 50
# 62
# 38
# 15.420000000000005
# 52.959999999999994
# 17.555
# Total SSE =85.935000
#
#
# Cluster 0 50
# Cluster 1 62
# Cluster 2 38
#
#
# Cosine
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.006, 3.418, 1.464, 0.244]), 1: array([6.52      , 2.96545455, 5.48      , 1.98545455]), 2: array([5.94666667, 2.75777778, 4.20444444, 1.29777778])})
# 50
# 55
# 45
# 15.2404
# 51.008727272727285
# 27.61066666666667
# Total SSE =93.859794
#
#
# Cluster 0 50
# Cluster 1 55
# Cluster 2 45
# Median
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5. , 3.4, 1.5, 0.2]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5.85, 2.8 , 4.25, 1.3 ])})
# 50
# 54
# 46
# 15.420000000000005
# 50.00999999999998
# 28.410000000000007
# Total SSE =93.840000
#
#
# Cluster 0 50
# Cluster 1 54
# Cluster 2 46
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [133, 106, 77]
# Initial Cluster Centers
#
# [6.3 2.5 5.  1.9]
# [6.4 2.8 5.6 2.1]
# [6.7 3.  5.  1.7]
# Iteration=17
#
# Euclidean
# Mean
#
# Max Iteratins Run=11
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.88360656, 2.74098361, 4.38852459, 1.43442623]), 1: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 61
# 39
# 50
# 38.29081967213114
# 25.413846153846155
# 15.2404
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 0.4348045249527312
# 26.5230760221166 0
# 4.995531182067555
# 221.34879212275126 1
# 7.662212642538981
# 604.4594242497003 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.6, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 61
# 39
# 50
# 39.39000000000001
# 26.93
# 15.420000000000005
# Total SSE =81.740000
#
#
# Cluster 0 61
# Cluster 1 39
# Cluster 2 50
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333]), 1: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 63
# 37
# 50
# 41.31492063492064
# 22.58810810810811
# 15.2404
# Total SSE =79.143429
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
# Median
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.5, 1.4]), 1: array([6.7, 3. , 5.7, 2.1]), 2: array([5. , 3.4, 1.5, 0.2])})
# 63
# 37
# 50
# 42.05
# 24.02
# 15.420000000000005
# Total SSE =81.490000
#
#
# Cluster 0 63
# Cluster 1 37
# Cluster 2 50
#
#
# Cosine
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.93913043, 2.76304348, 4.21086957, 1.30217391]), 1: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 2: array([5.006, 3.418, 1.464, 0.244])})
# 46
# 54
# 50
# 27.911086956521736
# 48.92722222222223
# 15.2404
# Total SSE =92.078709
#
#
# Cluster 0 46
# Cluster 1 54
# Cluster 2 50
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.9, 2.8, 4.3, 1.3]), 1: array([6.4, 3. , 5.5, 2. ]), 2: array([5. , 3.4, 1.5, 0.2])})
# 47
# 53
# 50
# 29.06
# 49.13999999999998
# 15.420000000000005
# Total SSE =93.620000
#
#
# Cluster 0 47
# Cluster 1 53
# Cluster 2 50
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [46, 31, 114]
# Initial Cluster Centers
#
# [6.5 3.2 5.1 2. ]
# [5.4 3.4 1.5 0.4]
# [5.7 2.8 4.5 1.3]
# Iteration=18
#
# Euclidean
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.85384615, 3.07692308, 5.71538462, 2.05384615]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.88360656, 2.74098361, 4.38852459, 1.43442623])})
# 39
# 50
# 61
# 25.413846153846155
# 15.2404
# 38.29081967213114
# [5.91448424 3.07863556 3.85596974 1.24409079]
# 4.995531182067554
# 194.8257161006346 0
# 7.662212642538984
# 577.9363482275838 1
# 0.4348045249527312
# 604.4594242497004 2
# Total SSE =78.945066
# Total SSB =604.459424
#
#
#
# Cluster 0 39
# Cluster 1 50
# Cluster 2 61
# Median
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.6, 2.1]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 39
# 50
# 61
# 26.93
# 15.420000000000005
# 39.39000000000001
# Total SSE =81.740000
#
#
# Cluster 0 39
# Cluster 1 50
# Cluster 2 61
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=6
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.87027027, 3.08648649, 5.74594595, 2.08918919]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.9047619 , 2.74603175, 4.41269841, 1.43333333])})
# 37
# 50
# 63
# 22.58810810810811
# 15.2404
# 41.31492063492064
# Total SSE =79.143429
#
#
# Cluster 0 37
# Cluster 1 50
# Cluster 2 63
# Median
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.7, 3. , 5.7, 2.1]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.9, 2.8, 4.5, 1.4])})
# 37
# 50
# 63
# 24.02
# 15.420000000000005
# 42.05
# Total SSE =81.490000
#
#
# Cluster 0 37
# Cluster 1 50
# Cluster 2 63
#
#
# Cosine
# Mean
#
# Max Iteratins Run=4
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.53703704, 2.96481481, 5.49814815, 1.99444444]), 1: array([5.006, 3.418, 1.464, 0.244]), 2: array([5.93913043, 2.76304348, 4.21086957, 1.30217391])})
# 54
# 50
# 46
# 48.92722222222223
# 15.2404
# 27.911086956521736
# Total SSE =92.078709
#
#
# Cluster 0 54
# Cluster 1 50
# Cluster 2 46
# Median
#
# Max Iteratins Run=10000
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([6.4, 3. , 5.5, 2. ]), 1: array([5. , 3.4, 1.5, 0.2]), 2: array([5.9, 2.8, 4.3, 1.3])})
# 53
# 50
# 47
# 49.13999999999998
# 15.420000000000005
# 29.06
# Total SSE =93.620000
#
#
# Cluster 0 53
# Cluster 1 50
# Cluster 2 47
#
#
# **********XXXXX********
# Initial Cluster Center Indices
#  [11, 133, 30]
# Initial Cluster Centers
#
# [5.1 3.8 1.5 0.3]
# [6.3 2.5 5.  1.9]
# [4.8 3.4 1.6 0.2]
# Iteration=19
#
# Euclidean
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.28333333, 3.70833333, 1.49166667, 0.27916667]), 1: array([6.30103093, 2.88659794, 4.95876289, 1.69587629]), 2: array([4.77586207, 3.07241379, 1.62068966, 0.29655172])})
# 24
# 97
# 29
# 3.8495833333333342
# 123.79587628865977
# 15.808275862068967
# [5.45340878 3.22244835 2.69037307 0.75719823]
# 1.9304210810745257
# 46.33010594578862 0
# 6.857967680295207
# 711.5529709344238 1
# 1.8379977178688256
# 764.8549047526197 2
# Total SSE =143.453735
# Total SSB =764.854905
#
#
#
# Cluster 0 24
# Cluster 1 97
# Cluster 2 29
# Median
#
# Max Iteratins Run=2
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.2, 3.7, 1.5, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([4.8, 3.1, 1.5, 0.2])})
# 24
# 97
# 29
# 4.170000000000002
# 125.04000000000002
# 16.54
# Total SSE =145.750000
#
#
# Cluster 0 24
# Cluster 1 97
# Cluster 2 29
#
#
# Manhattan
# Mean
#
# Max Iteratins Run=7
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.19677419, 3.63225806, 1.47096774, 0.28064516]), 1: array([6.31458333, 2.89583333, 4.97395833, 1.703125  ]), 2: array([4.74782609, 2.93478261, 1.76956522, 0.33043478])})
# 31
# 96
# 23
# 6.08967741935484
# 118.65187500000002
# 18.18695652173913
# Total SSE =142.928509
#
#
# Cluster 0 31
# Cluster 1 96
# Cluster 2 23
# Median
#
# Max Iteratins Run=5
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.2, 3.7, 1.5, 0.2]), 1: array([6.3 , 2.9 , 4.9 , 1.65]), 2: array([4.8, 3.1, 1.5, 0.2])})
# 24
# 96
# 30
# 4.170000000000002
# 119.47000000000001
# 22.43
# Total SSE =146.070000
#
#
# Cluster 0 24
# Cluster 1 96
# Cluster 2 30
#
#
# Cosine
# Mean
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.10454545, 3.65454545, 1.37727273, 0.24545455]), 1: array([6.262, 2.872, 4.906, 1.676]), 2: array([4.92857143, 3.23214286, 1.53214286, 0.24285714])})
# 22
# 100
# 28
# 6.5972727272727285
# 139.796
# 5.767857142857144
# Total SSE =152.161130
#
#
# Cluster 0 22
# Cluster 1 100
# Cluster 2 28
# Median
#
# Max Iteratins Run=3
#
# Final Centroids: defaultdict(<class 'int'>, {0: array([5.1, 3.6, 1.4, 0.2]), 1: array([6.3, 2.9, 4.9, 1.6]), 2: array([4.9, 3.3, 1.5, 0.2])})
# 21
# 100
# 29
# 6.410000000000001
# 140.60000000000002
# 6.689999999999999
# Total SSE =153.700000
#
#
# Cluster 0 21
# Cluster 1 100
# Cluster 2 29
#
#
# **********XXXXX********

# %%
center = []
for i in range(len(centroids)):
  center.append(centroids[i])
cent = list(center)
cent_1 = np.array(cent)

# %%
iterations = np.arange(20)
#print(sse_1)
x = plt.subplot( )
x.plot(iterations, sse_1, label='SSE')
#x.plot(k_1, cv_auc, label='AUC CV')
plt.title('Iris Dataset : Random Iteration vs SSE')
plt.xlabel('Random Iteration')
plt.ylabel('SSE')
x.legend()
plt.show()

# %%
iterations = np.arange(20)
print(sse_3)
x = plt.subplot( )
x.plot(iterations, sse_3, label='SSE')
#x.plot(k_1, cv_auc, label='AUC CV')
plt.title('Iris Dataset : Random Iteration vs SSE')
plt.xlabel('Random Iteration')
plt.ylabel('AUC')
x.legend()
plt.show()
# Out:
# [96.56999999999998, 153.15000000000003, 153.70000000000002, 93.83999999999999, 93.83999999999999, 153.74, 96.57, 96.56999999999998, 93.61999999999998, 96.57, 93.83999999999999, 93.61999999999998, 93.61999999999998, 93.61999999999999, 155.59500000000003, 153.55, 93.83999999999999, 93.61999999999998, 93.61999999999999, 153.70000000000002]

# %%
import seaborn as sns
df_iris = pd.DataFrame(iris_data1, columns = colnames)
df_iris['cluster'] = cluster
sns.FacetGrid(df_iris, hue="cluster", size=5, hue_kws={"marker":["o", "o", "o", "x"]}).map(plt.scatter, "sepal_length", "sepal_width").add_legend()

# %%
plt.scatter(df_iris['sepal_length'], df_iris['sepal_width'],c=df_iris['cluster'], s=50, cmap='viridis')
centers = cent_1
plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.8);

# %%
plt.scatter(df_iris['petal_length'], df_iris['petal_width'],c=df_iris['cluster'], s=50, cmap='viridis')
centers = cent_1
plt.scatter(centers[:,2], centers[:,3], c='black', s=200, alpha=0.8);

# %%
print(classes)

# %%
print(cluster)

# %%
with open('cluster8.txt', 'w') as f:
  for i in cluster:
    f.write(str(i) +"\n")

# %%
sse = []
count1 = []
for rand_seed in range(1):
  classes,centroids,cluster,iter4=K_Means_predict(iris_data1,3,10000,rand_seed)
  SSE,count = sse_k(iris_data1,cluster,centroids,3)
  sse.append(SSE)
  count1.append(count)
  print("Total SSE =%2f"%SSE)
  #classes1,centroids1,cluster1,iter2=K_Means_predict_cos1(iris_data1,3,10000,rand_seed)
  for i in range(0,3):
    classes[i]=np.array(classes[i]).tolist()
  for i in range(0,3):
    classes1[i]=np.array(classes1[i]).tolist()  
  
  print("Iteration=%d \n"%rand_seed)
  print("Mean \n")
  # for i in range(0,3):
  #   print(len(classes[i]))
  # print("Median \n")  
  # for i in range(0,3):
  #   print(len(classes1[i]))
  # print("\n")
  #print(centroids)

# %%
# from collections import defaultdict
# iris_data1 = iris_data.to_numpy()
# for rand_seed in range(5):
#   classes,centroids,cluster=K_Means_predict(iris_data2,3,10000,rand_seed)
#   for i in range(0,3):
#     classes[i]=np.array(classes[i]).tolist()
  
#   for i in range(0,3):
#     print(len(classes[i]))
#   #print(centroids)

rand_seed = 0
classes,centroids,cluster,iter=K_Means_predict_cos1(iris_data1,3,10000,rand_seed)
for i in range(0,3):
  classes[i]=np.array(classes[i]).tolist()
  
for i in range(0,3):
  print(len(classes[i]))

# %%
print(cluster)

# %%
with open('cluster101.txt', 'w') as f:
  for i in cluster:
    f.write(str(i) +"\n")

# %%
SSE = sse_k(iris_data1,cluster,centroids,3)

# %%
print(SSE)
